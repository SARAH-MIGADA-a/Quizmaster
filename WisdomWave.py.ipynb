# %%
from tkinter import *
import tkinter as tk
from tkinter import ttk
import time

timer_label = None
timer_seconds = 600

def notebook1_right():
    remove_incorrect_notification(tab1)

    correct_label_1 = Label(tab1, text="Correct", font=("Arial", 40, "bold"), background="green", fg="yellow")
    correct_label_1.grid(row=7, column=0, sticky="w", pady=5)
    marks_label_1.config(text="Marks obtained: 1")

def notebook1_wrong():
    remove_correct_notification(tab1)

    incorrect_label_1 = Label(tab1, text="Incorrect", font=("Arial", 40, "bold"), background="red", fg="yellow")
    incorrect_label_1.grid(row=7, column=0, sticky="w", pady=5)
    marks_label_1.config(text="Marks obtained: 0")

def remove_correct_notification(tab):
    for widget in tab.grid_slaves():
        if isinstance(widget, Label) and widget.cget("text") == "Correct":
            widget.destroy()

def remove_incorrect_notification(tab):
    for widget in tab.grid_slaves():
        if isinstance(widget, Label) and widget.cget("text") == "Incorrect":
            widget.destroy()

def notebook2_right():
    remove_incorrect_notification(tab2)

    correct_label_2 = Label(tab2, text="Correct", font=("Arial", 40, "bold"), background="green", fg="yellow")
    correct_label_2.grid(row=7, column=0, sticky="w", pady=5)
    marks_label_2.config(text="Marks obtained: 1")

def notebook2_wrong():
    remove_correct_notification(tab2)

    incorrect_label_2 = Label(tab2, text="Incorrect", font=("Arial", 40, "bold"), background="red", fg="yellow")
    incorrect_label_2.grid(row=7, column=0, sticky="w", pady=5)
    marks_label_2.config(text="Marks obtained: 0")

def remove_correct_notification(tab):
    for widget in tab.grid_slaves():
        if isinstance(widget, Label) and widget.cget("text") == "Correct":
            widget.destroy()

def remove_incorrect_notification(tab):
    for widget in tab.grid_slaves():
        if isinstance(widget, Label) and widget.cget("text") == "Incorrect":
            widget.destroy()
def notebook3_right():
    remove_incorrect_notification(tab3)

    correct_label_3 = Label(tab3, text="Correct", font=("Arial", 40, "bold"), background="green", fg="yellow")
    correct_label_3.grid(row=7, column=0, sticky="w", pady=5)
    marks_label_3.config(text="Marks obtained: 1")

def notebook3_wrong():
    remove_correct_notification(tab3)

    incorrect_label_3 = Label(tab3, text="Incorrect", font=("Arial", 40, "bold"), background="red", fg="yellow")
    incorrect_label_3.grid(row=7, column=0, sticky="w", pady=5)
    marks_label_3.config(text="Marks obtained: 0")

def remove_correct_notification(tab):
    for widget in tab.grid_slaves():
        if isinstance(widget, Label) and widget.cget("text") == "Correct":
            widget.destroy()

def remove_incorrect_notification(tab):
    for widget in tab.grid_slaves():
        if isinstance(widget, Label) and widget.cget("text") == "Incorrect":
            widget.destroy()
            
def notebook4_right():
    remove_incorrect_notification(tab4)

    correct_label_4 = Label(tab4, text="Correct", font=("Arial", 40, "bold"), background="green", fg="yellow")
    correct_label_4.grid(row=7, column=0, sticky="w", pady=5)
    marks_label_4.config(text="Marks obtained: 1")

def notebook4_wrong():
    remove_correct_notification(tab4)

    incorrect_label_4 = Label(tab4, text="Incorrect", font=("Arial", 40, "bold"), background="red", fg="yellow")
    incorrect_label_4.grid(row=7, column=0, sticky="w", pady=5)
    marks_label_4.config(text="Marks obtained: 0")

def remove_correct_notification(tab):
    for widget in tab.grid_slaves():
        if isinstance(widget, Label) and widget.cget("text") == "Correct":
            widget.destroy()

def remove_incorrect_notification(tab):
    for widget in tab.grid_slaves():
        if isinstance(widget, Label) and widget.cget("text") == "Incorrect":
            widget.destroy()
            
def notebook5_right():
    remove_incorrect_notification(tab5)

    correct_label_5 = Label(tab5, text="Correct", font=("Arial", 40, "bold"), background="green", fg="yellow")
    correct_label_5.grid(row=7, column=0, sticky="w", pady=5)
    marks_label_5.config(text="Marks obtained: 1")

def notebook5_wrong():
    remove_correct_notification(tab5)

    incorrect_label_5 = Label(tab5, text="Incorrect", font=("Arial", 40, "bold"), background="red", fg="yellow")
    incorrect_label_5.grid(row=7, column=0, sticky="w", pady=5)
    marks_label_5.config(text="Marks obtained: 0")

def remove_correct_notification(tab):
    for widget in tab.grid_slaves():
        if isinstance(widget, Label) and widget.cget("text") == "Correct":
            widget.destroy()

def remove_incorrect_notification(tab):
    for widget in tab.grid_slaves():
        if isinstance(widget, Label) and widget.cget("text") == "Incorrect":
            widget.destroy()
            
def start_timer():
    global timer_label
    timer_label = Label(root, text="", font=("Arial", 20, "bold"))
    timer_label.pack(side="top", pady=10)
    update_timer()

def update_timer():
    global timer_seconds
    minutes, seconds = divmod(timer_seconds, 60)
    timer_label.config(text=f"Time left: {minutes:02d}:{seconds:02d}")
    if timer_seconds > 0:
        timer_seconds -= 1
        timer_label.after(1000, update_timer)
    else:
        close_application()

def close_application():
    root.destroy()

    
y = 0
root = tk.Tk()
root.title("WisdomWave")

root.geometry("1200x1800")
root.configure(bg="light blue")

notebook = ttk.Notebook(root)

tab1 = ttk.Frame(notebook)
tab2 = ttk.Frame(notebook)
tab3 = ttk.Frame(notebook)
tab4 = ttk.Frame(notebook)
tab5 = ttk.Frame(notebook)

notebook.add(tab1, text="Q1")
notebook.add(tab2, text="Q2")
notebook.add(tab3, text="Q3")
notebook.add(tab4, text="Q4")
notebook.add(tab5, text="Q5")

Label(tab1, text="What is the hypothetical point in space with infinite density and gravity, often associated with a collapsed star?", font=("San-Serif", 18, "bold")).grid(row=1, column=0, sticky="w", pady=5)

marks_label_1 = Label(tab1, text="", font=("Arial", 40, "bold"), background="black", fg="white")
marks_label_1.grid(row=8, column=0, sticky="w", pady=5)

Button(tab1, text="Quasar", font=("Arial", 30, "bold"), bg="light blue", command=notebook1_wrong).grid(row=2, column=0, sticky="w", pady=5)
Button(tab1, text="Pulsar", font=("Arial", 30, "bold"), bg="light pink", command=notebook1_wrong).grid(row=3, column=0, sticky="w", pady=5)
Button(tab1, text="Nebula", font=("Arial", 30, "bold"), bg="light green", command=notebook1_wrong).grid(row=4, column=0, sticky="w", pady=5)
Button(tab1, text="Singularity", font=("Arial", 30, "bold"), bg="light yellow", command=notebook1_right).grid(row=5, column=0, sticky="w", pady=5)

Label(tab2, text="What is the process by which a particle is both a particle and a wave at the same time?", font=("San-Serif",18,"bold")).grid(row=0, column=0,sticky="w", pady=5)

marks_label_2 = Label(tab2, text="", font=("Arial", 40, "bold"), background="black", fg="white")
marks_label_2.grid(row=8, column=0, sticky="w", pady=5)

Button(tab2, text="Entanglement", font=("Arial", 30,"bold"),bg="light green",command=notebook2_wrong).grid(row=1,column=0, sticky="w", pady=5)
Button(tab2, text="Superposition", font=("Arial", 30,"bold"),bg="light pink",command=notebook2_right).grid(row=2,column=0, sticky="w", pady=5)
Button(tab2, text="Quantum tunneling", font=("Arial", 30,"bold"),bg="light blue",command=notebook2_wrong).grid(row=3,column=0, sticky="w", pady=5)
Button(tab2, text="Complementarity", font=("Arial", 30,"bold"),bg="light yellow",command=notebook2_wrong).grid(row=4,column=0, sticky="w", pady=5)

Label(tab3, text="What is the phenomenon where a quantum particle can instantaneously affect another, regardless of distance?", font=("San-Serif",18,"bold")).grid(row=0, column=0, sticky="w", pady=5)

marks_label_3 = Label(tab3, text="", font=("Arial", 40, "bold"), background="black", fg="white")
marks_label_3.grid(row=8, column=0, sticky="w", pady=5)

Button(tab3, text="Entanglement", font=("Arial", 30,"bold"),bg="light yellow",command=notebook3_right).grid(row=1,column=0, sticky="w", pady=5)
Button(tab3, text="Interference", font=("Arial", 30,"bold"),bg="light pink",command=notebook3_wrong).grid(row=2,column=0, sticky="w", pady=5)
Button(tab3, text="Annihilation", font=("Arial", 30,"bold"),bg="light green",command=notebook3_wrong).grid(row=3,column=0, sticky="w", pady=5)
Button(tab3, text="Perturbation", font=("Arial", 30,"bold"),bg="light blue",command=notebook3_wrong).grid(row=4,column=0, sticky="w", pady=5)

Label(tab4, text="What is the name for the theoretical particles that make up dark matter and have very weak interactions with regular matter?" ,font=("San-Serif",15,"bold")).grid(row=0, column=0, sticky="w", pady=5)

marks_label_4 = Label(tab4, text="", font=("Arial", 40, "bold"), background="black", fg="white")
marks_label_4.grid(row=8, column=0, sticky="w", pady=5)

Button(tab4, text="Graviton", font=("Arial", 30,"bold"),bg="light blue",command=notebook4_wrong).grid(row=1,column=0, sticky="w", pady=5)
Button(tab4, text="Axion", font=("Arial", 30,"bold"),bg="light green",command=notebook4_right).grid(row=2,column=0, sticky="w", pady=5)
Button(tab4, text="Tachyon", font=("Arial", 30,"bold"),bg="light pink",command=notebook4_wrong).grid(row=3,column=0, sticky="w", pady=5)
Button(tab4, text="Lepton", font=("Arial", 30,"bold"),bg="light yellow",command=notebook4_wrong).grid(row=4,column=0, sticky="w", pady=5)

Label(tab5, text="What is the process where a massive star collapses under gravity, resulting in an extremely dense remnant?" ,font=("San-Serif",18,"bold")).grid(row=0, column=0, sticky="w", pady=5)

marks_label_5 = Label(tab5, text="", font=("Arial", 40, "bold"), background="black", fg="white")
marks_label_5.grid(row=8, column=0, sticky="w", pady=5)


Button(tab5, text="Supernova", font=("Arial", 30,"bold"),bg="light yellow",command=notebook5_wrong).grid(row=1,column=0, sticky="w", pady=5)
Button(tab5, text="Blackhole Formation", font=("Arial", 30,"bold"),bg="light pink",command=notebook5_right).grid(row=2,column=0, sticky="w", pady=5)
Button(tab5, text="Neutrino oscillation", font=("Arial", 30,"bold"),bg="light green",command=notebook5_wrong).grid(row=3,column=0, sticky="w", pady=5)
Button(tab5, text="Redshit", font=("Arial", 30,"bold"),bg="light blue",command=notebook5_wrong).grid(row=4,column=0, sticky="w", pady=5)

    
notebook.pack()
start_timer()
root.mainloop()
